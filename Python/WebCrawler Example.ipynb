# %% [markdown]
# ## Script to enable downloads of the recently featured wallpapers
#
# This script attempts to automatically download the top trending wallpapers on https://alpha.wallhaven.cc/

# %%
import urllib
import requests
from bs4 import BeautifulSoup

url = "https://alpha.wallhaven.cc/"
response = requests.get(url)
print(response)
page = str(BeautifulSoup(response.content))
i = 0;
#print(page)

def getImageURL(page):
    """returns all the urls in that page 
    """
    start_link = page.find("a href") #this is the tage that we use for links
    if start_link == -1:
        return None, 0
    start_quote = page.find('"', start_link)
    end_quote = page.find('"', start_quote + 1)
    url = page[start_quote + 1: end_quote]
    return url, end_quote
    
while True:
    url, n = getImageURL(page)
    page = page[n:]
    if url:
        if "wallpaper" in url: #this condition ensures we are only using images files
            print(url)
            urllib.urlretrieve(url, "/Users/adityabhargava/Pictures/wallapaper{}.jpg".format(i))
            i= i+1
            
    else:
        break
# Out:
# <Response [200]>
# https://alpha.wallhaven.cc/wallpaper/244196
# https://alpha.wallhaven.cc/wallpaper/427015
# https://alpha.wallhaven.cc/wallpaper/424714
# https://alpha.wallhaven.cc/wallpaper/426244
# https://alpha.wallhaven.cc/wallpaper/92085
# https://alpha.wallhaven.cc/wallpaper/424938
# https://alpha.wallhaven.cc/wallpaper/313179
# https://alpha.wallhaven.cc/wallpaper/420172
# https://alpha.wallhaven.cc/wallpaper/416958
# https://alpha.wallhaven.cc/wallpaper/422299
# https://alpha.wallhaven.cc/wallpaper/405789
# https://alpha.wallhaven.cc/wallpaper/226265
# https://alpha.wallhaven.cc/wallpaper/418517
# https://alpha.wallhaven.cc/wallpaper/310570
# https://alpha.wallhaven.cc/wallpaper/421287
# https://alpha.wallhaven.cc/wallpaper/421291
# https://alpha.wallhaven.cc/wallpaper/421473
# https://alpha.wallhaven.cc/wallpaper/419661
# https://alpha.wallhaven.cc/wallpaper/415131

# %%
import urllib
import requests
from bs4 import BeautifulSoup

url = "https://alpha.wallhaven.cc/"
response = requests.get(url)
print(response)
page = str(BeautifulSoup(response.content))
i = 0;
#print(page)

def getURL(page):
    """returns all the urls in that page 
    """
    start_link = page.find("a href") #this is the tage that we use for links
    if start_link == -1:
        return None, 0
    start_quote = page.find('"', start_link)
    end_quote = page.find('"', start_quote + 1)
    url = page[start_quote + 1: end_quote]
    return url, end_quote

def getImageUrl(page):
    """returns all the images' links on the page 
    """
    start_link = page.find("src") #this is the tage that we use for links
    if start_link == -1:
        return None, 0
    start_quote = page.find('"', start_link)
    end_quote = page.find('"', start_quote + 1)
    url = page[start_quote + 1: end_quote]
    return url, end_quote
    
    
while True:
    url, n = getURL(page)
    page = page[n:]
    if url:
        if "wallpaper" in url: #this condition leads us to the directory of the website containing the image
            #even though we have the url of the image, this is not enough.. The page has a link embedded that we must scrape
            print(url)
            response2 = requests.get(url)
            print(response2)
            page2 = str(BeautifulSoup(response2.content))
            while True:
                url2, n2 = getImageURL(page2)
                page2 = page2[n2:]
                if url2:
                    print(url2)
                else:
                    break
            #urllib.urlretrieve(url, "/Users/adityabhargava/Pictures/wallapaper{}.jpg".format(i))
            #i= i+1
            
    else:
        break
# Out:
# <Response [200]>
# https://alpha.wallhaven.cc/wallpaper/244196
# <Response [200]>
# https://alpha.wallhaven.cc
# https://alpha.wallhaven.cc/untagged
# https://alpha.wallhaven.cc/tags
# https://alpha.wallhaven.cc/rules
# https://alpha.wallhaven.cc/about
# https://alpha.wallhaven.cc/faq
# https://alpha.wallhaven.cc/stats
# https://alpha.wallhaven.cc/team
# https://alpha.wallhaven.cc/contact
# http://facebook.com/wallhavencc
# https://google.com/+WallhavenCcc
# http://twitter.com/wallhaven
# https://alpha.wallhaven.cc/about#Copyright
# https://alpha.wallhaven.cc
# https://alpha.wallhaven.cc/privacy-policy
# https://alpha.wallhaven.cc/terms
# https://alpha.wallhaven.cc/about#Copyright
# https://alpha.wallhaven.cc
# https://alpha.wallhaven.cc/privacy-policy
# https://alpha.wallhaven.cc/terms
# https://alpha.wallhaven.cc/wallpaper/427015
# <Response [200]>
# https://alpha.wallhaven.cc
# https://alpha.wallhaven.cc/untagged
# https://alpha.wallhaven.cc/tags
# ...

# %%
import urllib
import requests
from bs4 import BeautifulSoup

url = "https://alpha.wallhaven.cc/wallpaper/427015"
response = requests.get(url)
print(response)
page = str(BeautifulSoup(response.content))
i = 0;
#print(page)


def getImageUrl(page):
    """returns all the images' links on the page 
    """
    start_link = page.find("img") #this is the tage that we use for links
    print(start_link)
    if start_link == -1:
        return None, 0
    start_quote = page.find('"', start_link)
    end_quote = page.find('"', start_quote + 1)
    url = page[start_quote + 1: end_quote]
    return url, end_quote


while True:
    url, n = getImageURL(page)
    page = page[n:]
    if url:
        print(url)
            
    else:
        break
# Out:
# <Response [200]>
# https://alpha.wallhaven.cc
# https://alpha.wallhaven.cc/untagged
# https://alpha.wallhaven.cc/tags
# https://alpha.wallhaven.cc/rules
# https://alpha.wallhaven.cc/about
# https://alpha.wallhaven.cc/faq
# https://alpha.wallhaven.cc/stats
# https://alpha.wallhaven.cc/team
# https://alpha.wallhaven.cc/contact
# http://facebook.com/wallhavencc
# https://google.com/+WallhavenCcc
# http://twitter.com/wallhaven
# https://alpha.wallhaven.cc/about#Copyright
# https://alpha.wallhaven.cc
# https://alpha.wallhaven.cc/privacy-policy
# https://alpha.wallhaven.cc/terms
# https://alpha.wallhaven.cc/about#Copyright
# https://alpha.wallhaven.cc
# https://alpha.wallhaven.cc/privacy-policy
# https://alpha.wallhaven.cc/terms
